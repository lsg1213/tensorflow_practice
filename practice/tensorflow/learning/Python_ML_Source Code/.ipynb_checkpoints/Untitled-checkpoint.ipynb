# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
marathon_train.head()
# Out:
#                     Name  Age M/F         City State Country   5K   10K   15K  \
# 0         Desisa, Lelisa   25   M         Ambo   NaN     ETH  883  1783  2697
# 1  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH  883  1783  2698
# 2         Chebet, Wilson   29   M     Marakwet   NaN     KEN  883  1783  2697
# 3       Kipyego, Bernard   28   M      Eldoret   NaN     KEN  883  1784  2701
# 4          Korir, Wesley   32   M       Kitale   NaN     KEN  883  1784  2698
#
#     20K  ...   25K   30K   35K   40K  Pace  Official Time  Overall  Gender  \
# 0  3629  ...  4567  5520  6479  7359   296           7757        1       1
# 1  3628  ...  4567  5519  6479  7362   298           7788        2       2
# 2  3629  ...  4567  5520  6479  7381   299           7822        3       3
# 3  3629  ...  4567  5520  6483  7427   300           7847        4       4
# 4  3628  ...  4567  5520  6479  7407   300           7849        5       5
#
#    Division  Year
# 0         1  2015
# 1         2  2015
# 2         3  2015
# 3         4  2015
# 4         5  2015
#
# [5 rows x 21 columns]

# %%
marathon_2015_2017 = pd.read_csv('./data/marathon_2015_2017.csv')

# training set
marathon_train = marathon_2015_2017[marathon_2015_2017['Year'] != 2017]
marathon_test = marathon_2015_2017[marathon_2015_2017['Year'] == 2017]

# record
record_train = pd.DataFrame(marathon_train, columns=['Age', 'M/F', 'Pace'])
record_test = pd.DataFrame(marathon_test, columns=['Age', 'M/F', 'Pace'])

def learning(age = 26, gender = 'M', rank = 1, step = 1, training = 100):
    model = tf.keras.models.Sequential()
    train = record_train[record_train['Age'] == age]
    train = train[train['M/F'] == gender].sort_values(['Pace'], ascending=[True])
    test = record_test[record_train['Age'] == age]
    test = test[test['M/F'] == gender].sort_values(['Pace'], ascending=[True])

    model.add(tf.keras.layers.Dense(1, input_shape=(3,)))
    
    sgd = tf.keras.optimizers.SGD(lr=step)
    
    model.compile(loss='categorical_hinge',
                 optimizer=sgd,
                 metrics=['accuracy'])
    model.summary()
    history = model.fit(np.array(train[0:2]), np.array(train[2]), epochs=step)
    for i in range(training):
        if i % 10 == 0:
            print('{}\t {}'.format(i, history.history['loss'][i]))
    
    #testing
    pace = model.predict(np.array([age, gender]))
    print('predict: {}, real: {}'.format(pace[rank], test[rank] - pace[rank]))

# %%
learning()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-5dd13db31c92> in <module>
# ----> 1 learning()
#
# <ipython-input-49-38ca98a7a0fc> in learning(age, gender, rank, step, training)
#      12     model = tf.keras.models.Sequential()
#      13     train = record_train[record_train['Age'] == age]
# ---> 14     train = train[train['M/F'] == gender].sort_values(['pace'], ascending=[True])
#      15     test = record_test[record_train['Age'] == age]
#      16     test = test[test['M/F'] == gender].sort_values(['pace'], ascending=[True])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4991
#    4992             by = by[0]
# -> 4993             k = self._get_label_or_level_values(by, axis=axis)
#    4994
#    4995             if isinstance(ascending, (tuple, list)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 'pace'
