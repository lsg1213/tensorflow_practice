# %%
import numpy as np
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.animation import FuncAnimation
import math
# Import pandas as a alias 'pd'
import pandas as pd

# Load the CSV files "marathon_results_2015 ~ 2017.csv" under "data" folder
marathon_2015_2017 = pd.read_csv("./data/marathon_2015_2017.csv")
marathon_2015_2017['M/F'] = marathon_2015_2017['M/F'].map({'M': 1, 'F': 0})

# Merge 2015, 2016 and 2017 files into marathon_2015_2017 file index by Official Time
# record = pd.DataFrame(marathon_2015_2017,columns=['5K',  '10K',  '15K',  '20K', 'Half',  '25K',  '30K',  '35K',  '40K',  'Official Time']).sort_values(by=['Official Time'])
marathon_2015_2016 = marathon_2015_2017[marathon_2015_2017['Year'] != 2017]
marathon_2017 = marathon_2015_2017[marathon_2015_2017['Year'] == 2017]

df_2015_2016 = pd.DataFrame(marathon_2015_2016,columns=['M/F',  'Age',  'Pace',  '10K', '20K',  '30K',  'Official Time'])
df_2017 = pd.DataFrame(marathon_2017,columns=['M/F',  'Age',  'Pace',  '10K', '20K',  '30K',  'Official Time'])

# Dataframe to List
record_2015_2016 = df_2015_2016.values.tolist()
record_2017 = df_2017.values.tolist()

# X and Y data from 0km to 30km    
x_train = [ r[0:3] for r in record_2015_2016]
y_train = [ r[3:7] for r in record_2015_2016]

x_test = [ r[0:3] for r in record_2017]
y_test = [ r[3:7] for r in record_2017]

gender_list = ['Female', 'Male']
grad_fig = Figure(figsize=(10, 6), dpi=100)
grad_ax = grad_fig.add_subplot(111)
grad_ax.set_xlim(15, 88)
grad_ax.set_ylim(0, 1300)
grad_ax.set_ylabel("Pace : Runner's overall minute per mile pace")
grad_ax.set_xlabel("Age : Age on race day")
g_xdata, g_ydata = [], []
gn, = grad_ax.plot([], [], 'ro')

# %%
def seconds_to_hhmmss(seconds):
    hours = seconds // (60*60)
    seconds %= (60*60)
    minutes = seconds // 60
    seconds %= 60
    return "%02i:%02i:%02i" % (hours, minutes, seconds)

def learning(): 
    """
    MAchine Learning, Tensorflow2 
    """
    # Tensorflow2 Linear Regression
    import tensorflow as tf
    import numpy as np

        
    t_a = 1
    runner = x_test[t_a]
    t_g = int(runner[0])
    t_y = int(runner[1])
    t_p = int(runner[2])

    t_t = 2000
    t_r = 0.000001

    # Define Sequential model and Dense
    model =  tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(4, input_shape=(3,)))

    # Stochastic gradient descent (SGD) Optimizer
    sgd = tf.keras.optimizers.SGD(lr=t_r)
    # Mean Square Error (MSE) loss function
    model.compile(loss='mse', optimizer=sgd)

    # prints summary of the model to the terminal
    model.summary()
    # Train the model
    history = model.fit(np.array(x_train), np.array(y_train), epochs=t_t)

    # Fit the line
    log_ScrolledText.insert(END, '\nGender :'+gender_list[t_g]+', Age :'+str(t_y)+', Pace :'+str(t_p)+'\n', 'TITLE')
    log_ScrolledText.insert(END, '\n\nCost Decent\n\n','HEADER')
    log_ScrolledText.insert(END, "%20s %20s" % ('Step', 'Cost')+'\n\n')
    for step in range(t_t):
        if step % 100 == 0:
            cost_val = history.history['loss'][step]
            log_ScrolledText.insert(END, "%20i %20.5f" % (step, cost_val)+'\n')

    # Testing our model
    winner = [ t_g, t_y, t_p ]
    time = model.predict(np.array([winner]))

    print('\n\nRecords Prediction\n\n')
    print("%20s %30s %30s %20s" % ('Distance(km)', 'Real record', 'ML Prediction', 'Variation(Second)')+'\n')
    distance = [ 10., 20., 30., 42.195 ]
    for i in range(len(time[0])):
        dist_time = int(time[0][i])
        real_time = seconds_to_hhmmss(y_test[t_a][i]) + '(' + str(y_test[t_a][i]) + ')'
        ml_time = seconds_to_hhmmss(dist_time) + '(' + str(dist_time) + ')'
        variation = y_test[t_a][i] - dist_time

        print("%20.3f %30s %30s %20.3f" % (distance[i], real_time, ml_time, variation))    
learning()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 4)                 16
# =================================================================
# Total params: 16
# Trainable params: 16
# Non-trainable params: 0
# _________________________________________________________________
# Train on 53228 samples
# Epoch 1/2000
# 53228/53228 [==============================] - 8s 147us/sample - loss: 295005.8016
# Epoch 2/2000
# 53228/53228 [==============================] - 6s 107us/sample - loss: 110812.1000
# Epoch 3/2000
# 53228/53228 [==============================] - 6s 108us/sample - loss: 110631.5263
# Epoch 4/2000
#  8992/53228 [====>.........................] - ETA: 4s - loss: 100610.3361
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-54688ee998a5> in <module>
#      61
#      62         print("%20.3f %30s %30s %20.3f" % (distance[i], real_time, ml_time, variation))
# ---> 63 learning()
#
# <ipython-input-5-54688ee998a5> in learning()
#      36     model.summary()
#      37     # Train the model
# ---> 38     history = model.fit(np.array(x_train), np.array(y_train), epochs=t_t)
#      39
#      40     # Fit the line
#
# ~/anaconda3/envs/ten2.0/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ~/anaconda3/envs/ten2.0/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# ~/anaconda3/envs/ten2.0/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     119       current_batch_size = num_samples - step * batch_size
#     120     with training_context.on_batch(
# --> 121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
#     123         batch_outs = execution_function(iterator)
#
# ~/anaconda3/envs/ten2.0/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/ten2.0/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in on_batch(self, step, mode, size)
#     691     batch_logs = {'batch': step, 'size': size}
#     692     self.callbacks._call_batch_hook(
# --> 693         mode, 'begin', step, batch_logs)
#     694     self.progbar.on_batch_begin(step, batch_logs)
#     695     try:
#
# ~/anaconda3/envs/ten2.0/lib/python3.7/site-packages/tensorflow_core/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     236     self._delta_ts[hook_name].append(time.time() - t_before_callbacks)
#     237
# --> 238     delta_t_median = np.median(self._delta_ts[hook_name])
#     239     if (self._delta_t_batch > 0. and
#     240         delta_t_median > 0.95 * self._delta_t_batch and delta_t_median > 0.1):
#
# <__array_function__ internals> in median(*args, **kwargs)
#
# ~/anaconda3/envs/ten2.0/lib/python3.7/site-packages/numpy/lib/function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3484     """
#    3485     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3486                     overwrite_input=overwrite_input)
#    3487     if keepdims:
#    3488         return r.reshape(k)
#
# ~/anaconda3/envs/ten2.0/lib/python3.7/site-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3392         keepdim = (1,) * a.ndim
#    3393
# -> 3394     r = func(a, **kwargs)
#    3395     return r, keepdim
#    3396
#
# ~/anaconda3/envs/ten2.0/lib/python3.7/site-packages/numpy/lib/function_base.py in _median(a, axis, out, overwrite_input)
#    3525         axis = 0
#    3526
# -> 3527     indexer = [slice(None)] * part.ndim
#    3528     index = part.shape[axis] // 2
#    3529     if part.shape[axis] % 2 == 1:
#
# KeyboardInterrupt:
