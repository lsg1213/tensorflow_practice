# %%
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt

# %%
imgFile = './training_set/cats/cat.1.jpg'

# %%
img = tf.io.

# %%
plt.figure(figsize=(8,8))
plt.imshow(img)

# %%
imgc_file = cv2.imwrite()
imgc
# Out:
# array([[255],
#        [216],
#        [255],
#        ...,
#        [167],
#        [255],
#        [217]], dtype=uint8)

# %%
plt.figure(figsize=(8,8))
plt.imshow(imgc.ast
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-21528a630f69> in <module>
#       1 plt.figure(figsize=(8,8))
# ----> 2 plt.imshow(imgc.astype(uint8))
#
# AttributeError: 'tuple' object has no attribute 'astype'

# %%
a = cv2.imdecode(np.array(imgc[1]), 1)
cv2.imshow('a',a)
