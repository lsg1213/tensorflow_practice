# %% [markdown]
# [![class](https://img.youtube.com/vi/VeZTpY4qFag/1.jpg)](https://www.youtube.com/watch?v=VeZTpY4qFag&list=PLBHVuYlKEkUKnfbWvRCrwSuSeYh_QUlRl&index=28)
# Video

# %%
import pandas as pd

# %%
ipl_data = {'Team':['Riders','Riders','Devils','Devils','Kings',
                   'kings','Kings','Kings','Riders','Royals','Royals','Riders'],
           'Rank':[1,2,2,3,3,4,1,1,2,4,1,2],
           'Year':[2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
           'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}

df = pd.DataFrame(ipl_data)

# %%
grouped = df.groupby('Team')
for name, group in grouped:
    print(name)
    print(group)
# Out:
# Devils
#      Team  Rank  Year  Points
# 2  Devils     2  2014     863
# 3  Devils     3  2015     673
# Kings
#     Team  Rank  Year  Points
# 4  Kings     3  2014     741
# 6  Kings     1  2016     756
# 7  Kings     1  2017     788
# Riders
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 8   Riders     2  2016     694
# 11  Riders     2  2017     690
# Royals
#       Team  Rank  Year  Points
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# kings
#     Team  Rank  Year  Points
# 5  kings     4  2015     812

# %%
for data in grouped:
    print(data)
# Out:
# ('Devils',      Team  Rank  Year  Points
# 2  Devils     2  2014     863
# 3  Devils     3  2015     673)
# ('Kings',     Team  Rank  Year  Points
# 4  Kings     3  2014     741
# 6  Kings     1  2016     756
# 7  Kings     1  2017     788)
# ('Riders',       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 8   Riders     2  2016     694
# 11  Riders     2  2017     690)
# ('Royals',       Team  Rank  Year  Points
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804)
# ('kings',     Team  Rank  Year  Points
# 5  kings     4  2015     812)

# %%
for name,group in grouped:
    print(type(name))
    print(type(group))
# Out:
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>

# %%
grouped.get_group('Devils')
# Out:
#      Team  Rank  Year  Points
# 2  Devils     2  2014     863
# 3  Devils     3  2015     673

# %% [markdown]
# # Aggregation

# %%
grouped.agg(sum)
# Out:
#         Rank  Year  Points
# Team
# Devils     5  4029    1536
# Kings      5  6047    2285
# Riders     7  8062    3049
# Royals     5  4029    1505
# kings      4  2015     812

# %%
import numpy as np
grouped.agg(np.mean)
# Out:
#             Rank         Year      Points
# Team
# Devils  2.500000  2014.500000  768.000000
# Kings   1.666667  2015.666667  761.666667
# Riders  1.750000  2015.500000  762.250000
# Royals  2.500000  2014.500000  752.500000
# kings   4.000000  2015.000000  812.000000

# %%
grouped['Points'].agg([np.sum, np.mean, np.std]).fillna(0)
# Out:
#          sum        mean         std
# Team
# Devils  1536  768.000000  134.350288
# Kings   2285  761.666667   24.006943
# Riders  3049  762.250000   88.567771
# Royals  1505  752.500000   72.831998
# kings    812  812.000000    0.000000

# %% [markdown]
# # Transformation

# %%
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
score = lambda x: (x.max())
grouped.transform(score)
# Out:
#     Rank  Year  Points
# 0      2  2017     876
# 1      2  2017     876
# 2      3  2015     863
# 3      3  2015     863
# 4      3  2017     788
# 5      4  2015     812
# 6      3  2017     788
# 7      3  2017     788
# 8      2  2017     876
# 9      4  2015     804
# 10     4  2015     804
# 11     2  2017     876

# %%
score = lambda x: (x - x.mean()) / x.std()
grouped.transform(score)
# Out:
#         Rank      Year    Points
# 0  -1.500000 -1.161895  1.284327
# 1   0.500000 -0.387298  0.302029
# 2  -0.707107 -0.707107  0.707107
# 3   0.707107  0.707107 -0.707107
# 4   1.154701 -1.091089 -0.860862
# 5        NaN       NaN       NaN
# 6  -0.577350  0.218218 -0.236043
# 7  -0.577350  0.872872  1.096905
# 8   0.500000  0.387298 -0.770596
# 9   0.707107 -0.707107 -0.707107
# 10 -0.707107  0.707107  0.707107
# 11  0.500000  1.161895 -0.815759

# %%
df.groupby('Team').filter(lambda x: len(x) >= 3)
# must be a boolean in the filter argument
# x is grouped dataframe number
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 4    Kings     3  2014     741
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 11  Riders     2  2017     690

# %%
df.groupby('Team').filter(lambda x: x['Rank'].sum() > 2)
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
df.groupby('Team').filter(lambda x: x['Points'].sum() > 1000)
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
df.groupby('Team').filter(lambda x: x['Rank'].mean() > 1)
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690
